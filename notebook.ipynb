# %%
print("starting")

from services.market_data import get_market_data_and_detect_anomalies

results, flagged = get_market_data_and_detect_anomalies()

print("done")
print(flagged)
# Out:
# starting
# done
# []

# %%
from services.news_service import NewsService

news_service = NewsService()

if not flagged:
    print("No anomalies flagged — skipping news fetch.")
    news = None
else:
    news = news_service.get_news(flagged[0])

news
# Out:
# No anomalies flagged — skipping news fetch.

# %%
news_service.get_news(flagged[1])
# Out:
# {'ticker': 'NVDA',
#  'move_time': '2026-06-05 15:30:00',
#  'retrieved_at': '2026-06-05T20:23:30.541254',
#  'article_count': 10,
#  'articles': [{'title': 'Nvidia At $5 Trillion Requires A Grid That Doesn’t Exist (NASDAQ:NVDA) - Seeking Alpha',
#    'url': 'https://seekingalpha.com/article/4910245-nvidia-at-5-trillion-requires-a-grid-that-doesnt-exist',
# ...
